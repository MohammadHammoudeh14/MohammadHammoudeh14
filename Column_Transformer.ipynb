# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadHammoudeh14/MohammadHammoudeh14/blob/main/Column_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)
import missingno
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
# Set pandas as the default output for sklearn
from sklearn import set_config
set_config(transform_output='pandas')

# %%
url ='/content/drive/MyDrive/AXSOSACADEMY/02-IntroML/Week05/Data/ames-housing-dojo-for-ml.csv'

# %%
df = pd.read_csv(url)
df = df.set_index('PID')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2930 entries, 907227090 to 902201120
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MS Zoning         2930 non-null   object
#  1   Lot Frontage      2440 non-null   float64
#  2   Lot Area          2930 non-null   int64
#  3   Street            2930 non-null   object
#  4   Alley             198 non-null    object
#  5   Utilities         2930 non-null   object
#  6   Neighborhood      2930 non-null   object
#  7   Bldg Type         2930 non-null   object
#  8   House Style       2930 non-null   object
#  9   Overall Qual      2930 non-null   int64
#  10  Overall Cond      2930 non-null   int64
#  11  Year Built        2930 non-null   int64
#  12  Year Remodeled    2930 non-null   int64
#  13  Exter Qual        2930 non-null   object
#  14  Exter Cond        2930 non-null   object
#  15  Bsmt Unf Sqft     2929 non-null   float64
#  16  Total Bsmnt Sqft  2929 non-null   float64
#  17  Central Air       2930 non-null   object
#  18  Living Area Sqft  2930 non-null   float64
#  19  Bedroom           2930 non-null   int64
#  20  Kitchen           2930 non-null   int64
#  21  Total Rooms       2930 non-null   int64
#  22  Garage Type       2773 non-null   object
#  23  Garage Yr Blt     2770 non-null   float64
#  24  Garage Cars       2929 non-null   float64
#  25  Garage Area       2929 non-null   float64
#  26  Garage Qual       2771 non-null   object
#  27  Garage Cond       2771 non-null   object
#  28  Paved Drive       2930 non-null   object
#  29  Fence             572 non-null    object
#  30  SalePrice         2930 non-null   float64
#  31  Month             2930 non-null   int64
#  32  Year              2930 non-null   int64
#  33  Total Full Baths  2928 non-null   float64
#  34  Total Half Baths  2925 non-null   float64
# dtypes: float64(10), int64(10), object(15)
# memory usage: 824.1+ KB
#           MS Zoning  Lot Frontage  Lot Area Street Alley Utilities  \
# PID
# 907227090        RL          60.0      7200   Pave   NaN    AllPub
# 527108010        RL         134.0     19378   Pave   NaN    AllPub
# 534275170        RL           NaN     12772   Pave   NaN    AllPub
# 528104050        RL         114.0     14803   Pave   NaN    AllPub
# 533206070        FV          32.0      3784   Pave  Pave    AllPub
#
#           Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  \
# PID
# 907227090      CollgCr      1Fam      1Story             5             8
# 527108010      Gilbert      1Fam      2Story             7             5
# 534275170        NAmes      1Fam      1Story             6             8
# 528104050      NridgHt      1Fam      1Story            10             5
# 533206070      Somerst    TwnhsE      1Story             8             5
#
#            Year Built  Year Remodeled Exter Qual Exter Cond  Bsmt Unf Sqft  \
# PID
# 907227090        1972            1972         TA         TA          427.0
# 527108010        2005            2006         Gd         TA         1335.0
# 534275170        1960            1998         TA         Gd          460.0
# 528104050        2007            2008         Ex         TA          442.0
# 533206070        2006            2007         Gd         TA         1451.0
#
#            Total Bsmnt Sqft Central Air  Living Area Sqft  Bedroom  Kitchen  \
# PID
# 907227090             864.0           Y             864.0        3        1
# 527108010            1392.0           Y            2462.0        4        1
# 534275170             958.0           Y             958.0        2        1
# 528104050            2078.0           Y            2084.0        2        1
# 533206070            1511.0           Y            1565.0        2        1
#
#            Total Rooms Garage Type  Garage Yr Blt  Garage Cars  Garage Area  \
# PID
# 907227090            5      Detchd         1977.0          1.0        297.0
# 527108010            9      Attchd         2006.0          2.0        576.0
# 534275170            5      Attchd         1960.0          1.0        301.0
# 528104050            7      Attchd         2007.0          3.0       1220.0
# 533206070            5      Attchd         2006.0          2.0        476.0
#
#           Garage Qual Garage Cond Paved Drive  Fence  SalePrice  Month  Year  \
# PID
# 907227090          TA          TA           Y  MnPrv   119900.0      3  2006
# 527108010          TA          TA           Y    NaN   320000.0      3  2006
# 534275170          TA          TA           Y    NaN   151500.0      4  2007
# 528104050          TA          TA           Y    NaN   385000.0      6  2008
# 533206070          TA          TA           Y    NaN   193800.0      2  2007
#
#            Total Full Baths  Total Half Baths
# PID
# 907227090               1.0               0.0
# 527108010               3.0               1.0
# 534275170               1.0               0.0
# 528104050               3.0               0.0
# 533206070               3.0               0.0

# %%
y = df['SalePrice']
X = df.drop(columns=['SalePrice'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
num_cols = X_train.select_dtypes('number').columns
print('numeric columns',num_cols)
# Out:
# numeric columns Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#        'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Month', 'Year',
#        'Total Full Baths', 'Total Half Baths'],
#       dtype='object')

# %%
impute_median = SimpleImputer(strategy='median')
scaler = StandardScaler()

# %%
num_pipe = make_pipeline(impute_median, scaler)
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
num_tuple = ('numeric', num_pipe, num_cols)
num_tuple
# Out:
# ('numeric',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#         'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#         'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#         'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Month', 'Year',
#         'Total Full Baths', 'Total Half Baths'],
#        dtype='object'))

# %%
ord_cols = ['Exter Qual','Exter Cond', 'Garage Qual',"Garage Cond"]
print("Ordinal Columns:", ord_cols)
impute_na_ord = SimpleImputer(strategy='constant', fill_value='NA')
qual_cond_order = ['NA','Po', 'Fa', 'TA', 'Gd', 'Ex']
ordinal_category_orders = [qual_cond_order, qual_cond_order,
                           qual_cond_order, qual_cond_order]
ord_encoder = OrdinalEncoder(categories=ordinal_category_orders)
scaler_ord = StandardScaler()
ord_pipe = make_pipeline(impute_na_ord, ord_encoder, scaler_ord)
ord_pipe
# Out:
# Ordinal Columns: ['Exter Qual', 'Exter Cond', 'Garage Qual', 'Garage Cond']
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='NA', strategy='constant')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(categories=[['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                              'Ex'],
#                                             ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                              'Ex'],
#                                             ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                              'Ex'],
#                                             ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                              'Ex']])),
#                 ('standardscaler', StandardScaler())])

# %%
ord_tuple = ('ordinal', ord_pipe, ord_cols)
ord_tuple
# Out:
# ('ordinal',
#  Pipeline(steps=[('simpleimputer',
#                   SimpleImputer(fill_value='NA', strategy='constant')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['NA', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex']])),
#                  ('standardscaler', StandardScaler())]),
#  ['Exter Qual', 'Exter Cond', 'Garage Qual', 'Garage Cond'])

# %%
ohe_cols = X_train.select_dtypes('object').columns
print("OneHotEncoder Columns:", ohe_cols)
impute_na = SimpleImputer(strategy='constant',fill_value='Na')
ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
ohe_pipe = make_pipeline(impute_na,)
# Out:
# OneHotEncoder Columns: Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object')

# %%
ohe_tuple = ('categorical', ohe_pipe, ohe_cols)
ohe_tuple
# Out:
# ('categorical',
#  Pipeline(steps=[('simpleimputer',
#                   SimpleImputer(fill_value='Na', strategy='constant'))]),
#  Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#         'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#         'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#        dtype='object'))

# %%
col_transformer = ColumnTransformer([num_tuple, ord_tuple, ohe_tuple],
                                    verbose_feature_names_out=True)
col_transformer
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#        'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#        'Garage Yr Blt', 'Garage Cars', 'Garage...
#                                  ['Exter Qual', 'Exter Cond', 'Garage Qual',
#                                   'Garage Cond']),
#                                 ('categorical',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Na',
#                                                                 strategy='constant'))]),
#                                  Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object'))])

# %%
col_transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#        'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#        'Garage Yr Blt', 'Garage Cars', 'Garage...
#                                  ['Exter Qual', 'Exter Cond', 'Garage Qual',
#                                   'Garage Cond']),
#                                 ('categorical',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Na',
#                                                                 strategy='constant'))]),
#                                  Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object'))])

# %%
X_train_processed = col_transformer.transform(X_train)

# %%
X_test_processed = col_transformer.transform(X_test)

# %%
X_train_processed.head()
# Out:
#            numeric__Lot Frontage  numeric__Lot Area  numeric__Overall Qual  \
# PID
# 528221100               1.675751           0.771617              -0.052307
# 906475200              -0.332559           8.538205               0.648878
# 527212060               1.348817           0.314204               1.350062
# 533238045              -0.566083           0.388094               1.350062
# 909177100              -0.425969          -0.407523              -1.454675
#
#            numeric__Overall Cond  numeric__Year Built  \
# PID
# 528221100              -0.502685             1.151467
# 906475200              -0.502685             0.130173
# 527212060              -0.502685             1.118522
# 533238045              -0.502685             1.283247
# 909177100               0.389190            -0.133386
#
#            numeric__Year Remodeled  numeric__Bsmt Unf Sqft  \
# PID
# 528221100                 1.035599                0.388130
# 906475200                -0.442523                0.731384
# 527212060                 0.987918               -0.904794
# 533238045                 1.226325                0.118103
# 909177100                -0.823974               -1.277796
#
#            numeric__Total Bsmnt Sqft  numeric__Living Area Sqft  \
# PID
# 528221100                  -0.713416                  -0.076295
# 906475200                   1.067929                   0.075010
# 527212060                   0.218194                   2.055729
# 533238045                   1.309130                  -0.150965
# 909177100                  -2.324372                   2.269914
#
#            numeric__Bedroom  numeric__Kitchen  numeric__Total Rooms  \
# PID
# 528221100          0.186796         -0.201978              1.001397
# 906475200         -1.025606         -0.201978             -0.906809
# 527212060          1.399199         -0.201978              2.273535
# 533238045         -2.238009         -0.201978             -0.270740
# 909177100          3.824005          4.614965              2.273535
#
#            numeric__Garage Yr Blt  numeric__Garage Cars  numeric__Garage Area  \
# PID
# 528221100                1.141190              0.313192             -0.187267
# 906475200               -0.136577              0.313192              0.483883
# 527212060                1.099972              1.613510              1.182428
# 533238045                1.306063              1.613510              1.744003
# 909177100                0.028296             -2.287444             -2.145932
#
#            numeric__Month  numeric__Year  numeric__Total Full Baths  \
# PID
# 528221100       -0.429941      -1.358789                   0.016231
# 906475200        2.174559      -1.358789                   1.347830
# 527212060        0.314202      -0.601074                   2.679428
# 533238045       -0.802013       1.672072                   0.016231
# 909177100       -1.546156       1.672072                   1.347830
#
#            numeric__Total Half Baths  ordinal__Exter Qual  \
# PID
# 528221100                   1.046932             1.024832
# 906475200                  -0.810557            -0.679897
# 527212060                   1.046932             1.024832
# 533238045                   1.046932             1.024832
# 909177100                  -0.810557            -0.679897
#
#            ordinal__Exter Cond  ordinal__Garage Qual  ordinal__Garage Cond  \
# PID
# 528221100            -0.224365              0.284903              0.277006
# 906475200            -0.224365              0.284903              0.277006
# 527212060            -0.224365              0.284903              0.277006
# 533238045            -0.224365              0.284903              0.277006
# 909177100            -0.224365             -3.772982             -3.820146
#
#           categorical__MS Zoning categorical__Street categorical__Alley  \
# PID
# 528221100                     RL                Pave                 Na
# 906475200                     RL                Pave                 Na
# 527212060                     RL                Pave                 Na
# 533238045                     FV                Pave               Pave
# 909177100                     RH                Pave               Pave
#
#           categorical__Utilities categorical__Neighborhood  \
# PID
# 528221100                 AllPub                   Gilbert
# 906475200                 AllPub                   ClearCr
# 527212060                 AllPub                   StoneBr
# 533238045                 AllPub                   Somerst
# 909177100                 AllPub                     SWISU
#
#           categorical__Bldg Type categorical__House Style  \
# PID
# 528221100                   1Fam                   2Story
# 906475200                   1Fam                   1Story
# 527212060                   1Fam                   2Story
# 533238045                   1Fam                   1Story
# 909177100                 Duplex                   2Story
#
#           categorical__Exter Qual categorical__Exter Cond  \
# PID
# 528221100                      Gd                      TA
# 906475200                      TA                      TA
# 527212060                      Gd                      TA
# 533238045                      Gd                      TA
# 909177100                      TA                      TA
#
#           categorical__Central Air categorical__Garage Type  \
# PID
# 528221100                        Y                   Attchd
# 906475200                        Y                   Attchd
# 527212060                        Y                  BuiltIn
# 533238045                        Y                   Attchd
# 909177100                        Y                       Na
#
#           categorical__Garage Qual categorical__Garage Cond  \
# PID
# 528221100                       TA                       TA
# 906475200                       TA                       TA
# 527212060                       TA                       TA
# 533238045                       TA                       TA
# 909177100                       Na                       Na
#
#           categorical__Paved Drive categorical__Fence
# PID
# 528221100                        Y                 Na
# 906475200                        Y                 Na
# 527212060                        Y                 Na
# 533238045                        Y                 Na
# 909177100                        Y                 Na

# %%
col_transformer = ColumnTransformer([num_tuple, ohe_tuple],
                                    remainder='passthrough',
                                    verbose_feature_names_out=False)

# %%
col_transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#        'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#        'Garage Yr B...
#       dtype='object')),
#                                 ('categorical',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Na',
#                                                                 strategy='constant'))]),
#                                  Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object'))],
#                   verbose_feature_names_out=False)

# %%
# Fit on the training data
col_transformer.fit(X_train)
# Transform the training data
X_train_processed_demo = col_transformer.transform(X_train)
# Transorm the test data
X_test_processed_demo = col_transformer.transform(X_test)
# View the result
X_train_processed_demo.head()
# Out:
#            Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year Built  \
# PID
# 528221100      1.675751  0.771617     -0.052307     -0.502685    1.151467
# 906475200     -0.332559  8.538205      0.648878     -0.502685    0.130173
# 527212060      1.348817  0.314204      1.350062     -0.502685    1.118522
# 533238045     -0.566083  0.388094      1.350062     -0.502685    1.283247
# 909177100     -0.425969 -0.407523     -1.454675      0.389190   -0.133386
#
#            Year Remodeled  Bsmt Unf Sqft  Total Bsmnt Sqft  Living Area Sqft  \
# PID
# 528221100        1.035599       0.388130         -0.713416         -0.076295
# 906475200       -0.442523       0.731384          1.067929          0.075010
# 527212060        0.987918      -0.904794          0.218194          2.055729
# 533238045        1.226325       0.118103          1.309130         -0.150965
# 909177100       -0.823974      -1.277796         -2.324372          2.269914
#
#             Bedroom   Kitchen  Total Rooms  Garage Yr Blt  Garage Cars  \
# PID
# 528221100  0.186796 -0.201978     1.001397       1.141190     0.313192
# 906475200 -1.025606 -0.201978    -0.906809      -0.136577     0.313192
# 527212060  1.399199 -0.201978     2.273535       1.099972     1.613510
# 533238045 -2.238009 -0.201978    -0.270740       1.306063     1.613510
# 909177100  3.824005  4.614965     2.273535       0.028296    -2.287444
#
#            Garage Area     Month      Year  Total Full Baths  \
# PID
# 528221100    -0.187267 -0.429941 -1.358789          0.016231
# 906475200     0.483883  2.174559 -1.358789          1.347830
# 527212060     1.182428  0.314202 -0.601074          2.679428
# 533238045     1.744003 -0.802013  1.672072          0.016231
# 909177100    -2.145932 -1.546156  1.672072          1.347830
#
#            Total Half Baths MS Zoning Street Alley Utilities Neighborhood  \
# PID
# 528221100          1.046932        RL   Pave    Na    AllPub      Gilbert
# 906475200         -0.810557        RL   Pave    Na    AllPub      ClearCr
# 527212060          1.046932        RL   Pave    Na    AllPub      StoneBr
# 533238045          1.046932        FV   Pave  Pave    AllPub      Somerst
# 909177100         -0.810557        RH   Pave  Pave    AllPub        SWISU
#
#           Bldg Type House Style Exter Qual Exter Cond Central Air Garage Type  \
# PID
# 528221100      1Fam      2Story         Gd         TA           Y      Attchd
# 906475200      1Fam      1Story         TA         TA           Y      Attchd
# 527212060      1Fam      2Story         Gd         TA           Y     BuiltIn
# 533238045      1Fam      1Story         Gd         TA           Y      Attchd
# 909177100    Duplex      2Story         TA         TA           Y          Na
#
#           Garage Qual Garage Cond Paved Drive Fence
# PID
# 528221100          TA          TA           Y    Na
# 906475200          TA          TA           Y    Na
# 527212060          TA          TA           Y    Na
# 533238045          TA          TA           Y    Na
# 909177100          Na          Na           Y    Na

# %%
# Making a tuple for ColumnTransformer with a single transformer (no pipeline)
impute_median = SimpleImputer(strategy='median')
# Create the tuple without adding a pipeline:
#           (choose_a_name, pipeline_or_transformer, list_of_columns)
num_impute_tuple = ('number-imputed', impute_median, num_cols)
num_impute_tuple
# Out:
# ('number-imputed',
#  SimpleImputer(strategy='median'),
#  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#         'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#         'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#         'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Month', 'Year',
#         'Total Full Baths', 'Total Half Baths'],
#        dtype='object'))

# %%
# Instantiate with verbose_feature_names_out=False
col_transformer = ColumnTransformer([num_impute_tuple, ord_tuple, ohe_tuple],
                                    verbose_feature_names_out=False)

# %%
col_transformer
# Out:
# ColumnTransformer(transformers=[('number-imputed',
#                                  SimpleImputer(strategy='median'),
#                                  Index(['Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remodeled', 'Bsmt Unf Sqft', 'Total Bsmnt Sqft',
#        'Living Area Sqft', 'Bedroom', 'Kitchen', 'Total Rooms',
#        'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Month', 'Year',
#        'Total Full Baths', 'Total Half Baths'],
#       dtype='ob...
#                                   'Garage Cond']),
#                                 ('categorical',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Na',
#                                                                 strategy='constant'))]),
#                                  Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object'))],
#                   verbose_feature_names_out=False)

# %%
# Fit on the training data
col_transformer.fit(X_train)
# Transform the training  data
X_train_processed_demo = col_transformer.transform(X_train)
# Transform the test  data
X_test_processed_demo = col_transformer.transform(X_test)
# view results
X_train_processed_demo.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-19e00536e4de> in <cell line: 0>()
#       1 # Fit on the training data
# ----> 2 col_transformer.fit(X_train)
#       3 # Transform the training  data
#       4 X_train_processed_demo = col_transformer.transform(X_train)
#       5 # Transform the test  data
#
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py in fit(self, X, y, **params)
#     945         # we use fit_transform to make sure to set sparse_output_ (for which we
#     946         # need the transformed data) to have consistent output type in predict
# --> 947         self.fit_transform(X, y=y, **params)
#     948         return self
#     949
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y, **params)
#    1029         self._record_output_indices(Xs)
#    1030
# -> 1031         return self._hstack(list(Xs), n_samples=n_samples)
#    1032
#    1033     def transform(self, X, **params):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py in _hstack(self, Xs, n_samples)
#    1192                                     f"columns names: {dup_cols_in_transformer}.\n"
#    1193                                 )
# -> 1194                         raise ValueError(
#    1195                             err_msg
#    1196                             + "Either make sure that the transformers named above "
#
# ValueError: Duplicated feature names found before concatenating the outputs of the transformers: ['Exter Cond', 'Exter Qual', 'Garage Cond', 'Garage Qual'].
# Transformer ordinal has conflicting columns names: ['Exter Cond', 'Exter Qual', 'Garage Cond', 'Garage Qual'].
# Transformer categorical has conflicting columns names: ['Exter Cond', 'Exter Qual', 'Garage Cond', 'Garage Qual'].
# Either make sure that the transformers named above do not generate columns with conflicting names or set verbose_feature_names_out=True to automatically prefix to the output feature names with the name of the transformer to prevent any conflicting names.
